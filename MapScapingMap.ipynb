# %% [markdown]
# # MapScapingMap
#
# My plan is to create a map with the locations of all the interview partners Danial O'Donohue had on his [MapScaping](https://mapscaping.com/) Podcast.
# For this, I scrape his website for the basic info (episode, date, duration, title, categories) on each of the >200 podcast episodes. Then, I have to add the interviewees and their location etc. manually.

# %%
# import all necessary modules and packages
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import time
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
pd.set_option('display.max_rows', None)  # Optionally, ensure all rows are shown
# geocoded_df

# %%
base_url = 'https://mapscaping.com/podcasts/page/'
page_numbers = range(1, 13)

# Creating a list of URLs for pages 1 to 12 /!\ except page 4, see below!
links_list = [base_url + str(page_number) for page_number in page_numbers if page_number != 4]
# links_list

# %%
all_dfs = []

for url in tqdm(links_list): # Iterate over the links and track progress
    request = requests.get(url)
    soup = BeautifulSoup(request.text)

    date_soup = soup.findAll('span', class_= "blog-meta-date-display")
    dates = [date.text for date in date_soup]

    title_soup = soup.findAll('h2', class_= "secondline-blog-title")
    titles = [title.text for title in title_soup]
    titles = [title.replace('\n','').replace('\t','') for title in titles] # not nice, but works

    episode_soup = soup.findAll('div', class_= "blog-meta-serie-episode")
    episodes = [episode.text for episode in episode_soup]

    categories_soup = soup.findAll('span', class_= "blog-meta-category-list")
    categories = [category.text for category in categories_soup]
    categories = [category.replace('\n','').replace('\t','') for category in categories] # not nice, but works

    duration_soup = soup.findAll('span', class_= "blog-meta-time-slt")
    durations = [duration.text for duration in duration_soup]

    current_df = pd.DataFrame({'Episode': episodes, 'Date': dates, 'Title': titles, 'Duration': durations, 'Categories': categories})

    # Append the current DataFrame to the list
    all_dfs.append(current_df)

    # Adding a 5-second delay
    time.sleep(5)

# Concatenate all DataFrames in the list
result_df = pd.concat(all_dfs, ignore_index=True)
# Out:
# 100%|███████████████████████████████████████████| 11/11 [01:07<00:00,  6.13s/it]

# %%
result_df['Date'] = pd.to_datetime(result_df['Date'])
result_df['Episode'] = result_df['Episode'].str.replace('Episode ', '')
result_df
# Out:
#     Episode       Date                                              Title  \
# 0       230 2024-05-23                           GeoParquet for beginners
# 1       229 2024-05-16                              Finding Stuff Indoors
# 2       228 2024-05-01                          What is humanitarian GIS?
# 3       227 2024-04-12                           AI Autocomplete for QGIS
# 4       226 2024-03-21  GNSS receivers – why precise positioning will ...
# 5       225 2024-03-15  The Way You Talk About Your Geospatial Skills ...
# 6       224 2024-02-29                                  Modern Geospatial
# 7       223 2024-02-15               Introduction To LIDAR & Point Clouds
# 8       222 2024-01-26            Introduction to Cloud Native Geospatial
# 9       221 2024-01-09                                             GeeMap
# 10      220 2023-12-27                                     GPS Reimagined
# 11      219 2023-12-20                   The Business of QGIS Development
# 12      218 2023-12-14                      Making Beautiful Maps In Felt
# 13      217 2023-12-06    Planet – Imaging Everything, Every Day … Almost
# 14      216 2023-11-30  Fire Mapping, Maritime Search And Wide Angle I...
# 15      215 2023-11-22                    Personal Branding in Geospatial
# 16      214 2023-11-15                    Entity Resolution with Placekey
# 17      213 2023-10-04                        Strategic Buy-In For FOSS4G
# 18      212 2023-09-19                                   From GNSS to VPS
# 19      211 2023-08-30        Overture Maps And The Daylight Distribution
# 20      210 2023-08-16                       100 billion Points Every Day
# 21      209 2023-08-09                   Synthetic Data For Real Problems
# 22      208 2023-08-03                                          Hub Ocean
# 23      207 2023-07-19                             Felt – Upload Anything
# 24      206 2023-07-05                                   The Rapid Editor
# 25      205 2023-06-28  PostgreSQL – Listen and Notify Clients In Real...
# 26      204 2023-06-22  Applying For A Job, Getting Picked and Negotia...
# 27      203 2023-06-14                 Using Lasers To Talk To Satellites
# 28      202 2023-06-07    From Pixels to Patterns: AI in Spatial Analysis
# 29      201 2023-05-31              pygeoapi – A Python Geospatial Server
# 30      200 2023-05-24                            Big Data In The Browser
# 31      199 2023-05-17                             Rasters In A Database?
# 32      198 2023-05-10                  ChatGPT and Large Language Models
# 33      197 2023-05-07                           Spatial Knowledge Graphs
# 34      196 2023-04-26                          Computer Vision and GeoAI
# 35      195 2023-04-19                     Designing for Location Privacy
# 36      194 2023-04-13                     Hyperspectral vs Multispectral
# 37      193 2023-04-02                     All Of The Places In The World
# 38      192 2023-03-22           Planet Scale Tiled Maps Without A Server
# 39      191 2023-03-15                    Storytelling With  Point Clouds
# 40      190 2023-03-08                             Geospatial Archaeology
# 41      189 2023-03-01       Navigating the World of Geospatial Standards
# 42      188 2023-02-22               Making Money With Geospatial Content
# 43      187 2023-02-15                       Distributing Geospatial Data
# 44      186 2023-02-08  Geospatial Support for the UN World Food Progr...
# 45      185 2023-02-01               Aerial Imagery: The State Of The Art
# 46      184 2023-01-25        The technology stack and the cultural stack
# 47      183 2023-01-18    ChronoCards – Building a Business on ArcGIS Pro
# 48      182 2023-01-11  geospatial consulting – as a business and a ca...
# 49      181 2022-12-07                How Google Calculates Your Location
# 50      180 2022-11-30  Reduce and Reverse Tropical Forest Loss With N...
# 51      179 2022-11-15                       Cloud Optimized Point Clouds
# 52      178 2022-11-02                             Full Stack Cartography
# 53      177 2022-10-28                            Artificial Intelligence
# 54      176 2022-10-19                                  Mid-Career Change
# 55      175 2022-10-05         Peer To Peer Mapping and Digital Democracy
# 56      174 2022-09-28                         Thermal Imagery From Space
# 57      173 2022-09-22                                      I Quit My Job
# 58      172 2022-09-21        Monitoring Atmospheric Pollution From Space
# 59      171 2022-09-14                                          Hex Tiles
# 60      170 2022-09-08                           The Business of Web Maps
# 61      169 2022-08-31                     Finding Water Leaks From Space
# 62      168 2022-08-18       How To Keep Your Satellite Pointing At Earth
# 63      146 2022-02-09  Mapping Oceans With Sound  And Mapping the Sou...
# 64      145 2022-02-02  Urban Grammar- Form, Function, Culture and Sat...
# 65      144 2022-01-26                                 Geospatial Geology
# 66      143 2022-01-19              A Voice Interface for Geospatial Data
# 67      142 2022-01-12               From Hardware to Geospatial Software
# 68      141 2022-01-05                                 What Is Your Idea?
# 69      140 2021-12-22                                      Voice Message
# 70      139 2021-12-15                                  GEDI space lasers
# 71      138 2021-12-08                Cube Satellites Of The Stratosphere
# 72      137 2021-12-03                  Geospatial Education As A Service
# 126      83 2020-11-05   GIS education and training, online and in-person
# 127      82 2020-10-28                   Cloud Detection- an open problem
# 128      81 2020-10-21                A Business Built On Open Source GIS
# 129      80 2020-10-14                   location Privacy and Data Ethics
# 130      79 2020-10-01   Communicating with maps – The art of cartography
# 131      78 2020-09-23  Being self employed in the earth observation s...
# 132      77 2020-09-16                  Spatial SQL – GIS without the GIS
# 133      76 2020-09-11                                     Elastic Search
# 134      75 2020-09-02   Self-employment in the GIS / Geospatial industry
# 135      74 2020-08-26   The long tail of geospatial and spatial thinking
# 136      73 2020-08-19                          COVID-19 Spatial Research
# 137      72 2020-08-12                         Open Source GPU Processing
# 138      71 2020-08-05                      H3 geospatial indexing system
# 139      70 2020-07-29      Google BigQuery GIS – Geospatial in the Cloud
# 140      69 2020-07-22                      A one to one map of the world
# 141      68 2020-07-15                     The Spatial Internet of Things
# 142      67 2020-07-08              Spatially Enabling Customer Relations
# 143      66 2020-07-01  Everything happens somewhere And at some time ...
# 144      65 2020-06-24                              Polygons of Ownership
# 145      64 2020-06-17                   Jupyter notebooks for geospatial
# 146      63 2020-06-10                    Radio Frequency Data Collection
# 147      62 2020-06-03                     Hyper-accurate indoor location
# 148      61 2020-05-27                                      Digital Twins
# 149      60 2020-05-20                                  Geospatial Python
# 150      59 2020-05-13  Two mobile data collection apps you need to kn...
# 151      58 2020-05-06                          Rebranding GIS Geospatial
# 152      57 2020-04-29  GIS vs Computer-aided design – everything you ...
# 153      56 2020-04-22  Robotics, remote sensing and facilities manage...
# 154      55 2020-04-15  Advice for job seekers from a geospatial recru...
# 155      54 2020-04-08  The overlap between Business Intelligence tool...
# 156      53 2020-04-01    Dynamic vector tiles straight from the database
# 157      52 2020-03-25              Earth Observation, platforms and data
# 158      51 2020-03-18  Disrupting ESRI – Why it is hard to build a bi...
# 159      50 2020-03-12            QGIS – An opensource geospatial project
# 160      49 2020-03-03                                A Case Study in GIS
# 161      48 2020-02-26                              Serverless Geospatial
# 162      47 2020-02-19  Earth Observation – machine learning and artif...
# 163      46 2020-02-12  PostgreSQL – An open source geospatial databas...
# 164      45 2020-02-05  Geo-coding as a tool for risk assessment and t...
# 165      44 2020-01-29              Is R the language of geospatial data?
# 166      43 2020-01-22  Geospatial intelligence from the sky, automati...
# 167      42 2020-01-15  The evolution of geospatial file formats and d...
# 168      41 2019-12-26  Trends in geospatial and initiatives in the co...
# 169      40 2019-12-18  Travel Time – A better way of doing location b...
# 170      39 2019-12-11          Remote sensing – building the globe in 3D
# 171      38 2019-12-04  Addressing the world – a coordinate system fro...
# 172      37 2019-11-27             Don’t just make the dots, connect them
# 173      36 2019-11-20                     Building geospatial truth sets
# 174      35 2019-11-13  Mapping the interface between vehicle traffic ...
# 175      34 2019-11-06                      Creating maps for journalists
# 176      33 2019-10-30  Geomob – Geoinnovation for the people by the p...
# 177      32 2019-10-23                       Building footprints at scale
# 178      31 2019-10-16     Remote sensing and future of earth observation
# 179      30 2019-10-09    A marketplace for geospatial data and workflows
# 180      29 2019-10-02  Geospatial visualisations matter – Civil engin...
# 181      28 2019-09-25  Using the geomagnetic field of buildings to na...
# 182      27 2019-09-18                      The location context platform
# 183      26 2019-09-11                   Geospatial gives context to risk
# 184      25 2019-09-04            Inspirational geospatial visualizations
# 185      24 2019-08-28    Geospatial support for humanitarian emergencies
# 186      23 2019-08-21  Crowd source clean the planet – a geospatial a...
# 187      22 2019-08-14  Highways in the sky, risk islands and drone fl...
# 188      21 2019-08-08  Immersive maps give context to data – this is ...
# 189      20 2019-07-31  The Google Drive of geospatial – curation over...
# 190      19 2019-07-17           A geospatial story and some housekeeping
# 191      18 2019-07-10  Mapping the way we relate to the urban environ...
# 192      17 2019-07-03             Creating Global Activity Specific Maps
# 193      16 2019-06-25  Positioning as a service and the role of smart...
# 194      15 2019-06-19  A diary of your location – recording your trav...
# 195      14 2019-06-12  Scaling map data generation using computer vision
# 196      13 2019-06-05     A mapping platform for your outdoor adventures
# 197      12 2019-05-29           Tracking global air traffic in real time
# 198      11 2019-05-22  Translating between machine and human when tal...
# 199      10 2019-05-15                Mapping Personalised Workplace Risk
# 200       9 2019-05-08  Proof of location, bringing the blockchain to ...
# 201       8 2019-05-03  Geo-tagged audio – another way of augmenting r...
# 202       7 2019-04-25  Augmented reality will change the way you thin...
# 203       6 2019-04-16              Data discovery – the way it should be
# 204       5 2019-04-08  Powering location intelligence with geo social...
# 205       4 2019-04-02         freelance mappers create maps for machines
# 206       3 2019-03-10                    Bellerby & Co – The globemakers
# 207       2 2019-02-08  Indoor mapping and navigation: Manage, visuali...
# 208       1 2019-01-14  The future of collecting and updating geospati...
#
#      Duration                                         Categories
# 0       42:00                                     mapscaping.com
# 1       49:37                                     mapscaping.com
# 2       47:24                                     mapscaping.com
# 3       42:52                                     mapscaping.com
# 4       51:01                                     mapscaping.com
# 5       52:17                                     mapscaping.com
# 6       48:25                                     mapscaping.com
# 7       48:52                                     mapscaping.com
# 8       55:13                                     mapscaping.com
# 9       54:55                                     mapscaping.com
# 10      45:36                                     mapscaping.com
# 11      52:26                                     mapscaping.com
# 12      52:36                                     mapscaping.com
# 13      45:19                                     mapscaping.com
# 14      46:27                                     mapscaping.com
# 15      50:12                                     mapscaping.com
# 16      40:25                                     mapscaping.com
# 17      45:47                                     mapscaping.com
# 18      54:59                                     mapscaping.com
# 19      52:23  Geospatial Concepts, Geospatial Tech and Tools...
# 20      49:07     Geospatial Concepts, Geospatial Tech and Tools
# 21   01:02:36  Earth Observation, Geospatial Startups, Geospa...
# 22      38:53           Geospatial Concepts, Geospatial Startups
# 23      39:30                     Geospatial Tech and Tools, GIS
# 24      51:59                     Geospatial Tech and Tools, GIS
# 25      26:28                     Geospatial Tech and Tools, GIS
# 26   01:00:07                                  Geospatial Career
# 27      44:51  Earth Observation, Geospatial Concepts, Geospa...
# 28   01:05:50                                Geospatial Concepts
# 29      37:03                     Geospatial Tech and Tools, GIS
# 30      57:17     Geospatial Concepts, Geospatial Tech and Tools
# 199     32:29                                                GIS
# 200     26:14                                     mapscaping.com
# 201     29:25  Geospatial Concepts, Geospatial Startups, Geos...
# 202     29:52  Geospatial Concepts, Geospatial Tech and Tools...
# 203     38:40                                     mapscaping.com
# 204     33:48  Geospatial Concepts, Geospatial Startups, Geos...
# 205     43:43  Geospatial Startups, Geospatial Tech and Tools...
# 206     46:35                                                GIS
# 207     40:37  Geospatial Concepts, Geospatial Tech and Tools...
# 208     46:08  Earth Observation, Geospatial Startups, Geospa...

# %% [markdown]
# ### On page 3 of the website:
#
#
# Episode 162 (QGIS offline and in the field, July 20th, 2022) on page 3 does not have info on duration and episode, which makes it hard to make a dataframe out of it (as the arrays have different length)
# In the code below, I manually insert the missing information and bind page 3 to the rest of the scraped data.
#
# Episode 162 is located:
# between 'whitebox tools' and 'sentinel hub'
# between 161 and 163

# %%
base_url = 'https://mapscaping.com/podcasts/page/4'

response = requests.get(base_url)
soup = BeautifulSoup(response.text)

# %%
date_soup = soup.findAll('span', class_= "blog-meta-date-display")
dates = [date.text for date in date_soup]
print(len(dates))
dates
# Out:
# 21
# ['August 10, 2022',
#  'August 8, 2022',
#  'August 3, 2022',
#  'July 27, 2022',
#  'July 20, 2022',
#  'July 20, 2022',
#  'July 6, 2022',
#  'June 29, 2022',
#  'June 25, 2022',
#  'June 8, 2022',
#  'June 1, 2022',
#  'April 28, 2022',
#  'April 20, 2022',
#  'April 13, 2022',
#  'April 6, 2022',
#  'March 30, 2022',
#  'March 18, 2022',
#  'March 9, 2022',
#  'March 2, 2022',
#  'February 23, 2022',
#  'February 16, 2022']

# %%
title_soup = soup.findAll('h2', class_= "secondline-blog-title")
titles = [title.text for title in title_soup]
titles = [title.replace('\n','').replace('\t','') for title in titles] # not nice, but works
print(len(titles))
titles
# Out:
# 21
# ['Bathymetric Lidar and Blue Carbon',
#  'Re-Published – QGIS Offline And In The Field',
#  'The Open Geospatial Consortium',
#  'Monetizing An Open-Source Geospatial Project',
#  'Whitebox Tools Is The Backend To Many Frontends',
#  'QGIS Offline And In The Field',
#  'Sentinel Hub',
#  'Unstructured Data Is Dark Data',
#  'What Is Modern GIS?',
#  'FOSS4G',
#  'Building a web based mapping tool into a business',
#  'Digital twins – not just a buzzword',
#  'Build Your Own SaaS',
#  'Getting Your Dream Job in Earth Observation',
#  'Fake Satellite Imagery',
#  'Cloud Native Geospatial',
#  'Python Maps',
#  'Mentorship, Leadership and Career Advice',
#  'The Role Of Geospatial In Open Source Intelligence',
#  'Geospatial Design and User Experience Can Reduce The Time To Science',
#  'Business Ideas For Geospatial People']

# %%
episode_soup = soup.findAll('div', class_= "blog-meta-serie-episode")
episodes = [episode.text for episode in episode_soup]
episodes.insert(16, 'Episode 162')
print(len(episodes))
episodes
# Out:
# 21
# ['Episode 167',
#  'Episode 166',
#  'Episode 165',
#  'Episode 164',
#  'Episode 161',
#  'Episode 163',
#  'Episode 160',
#  'Episode 159',
#  'Episode 158',
#  'Episode 157',
#  'Episode 156',
#  'Episode 155',
#  'Episode 154',
#  'Episode 153',
#  'Episode 152',
#  'Episode 151',
#  'Episode 162',
#  'Episode 150',
#  'Episode 149',
#  'Episode 148',
#  'Episode 147']

# %%
categories_soup = soup.findAll('span', class_= "blog-meta-category-list")
categories = [category.text for category in categories_soup]
categories = [category.replace('\n','').replace('\t','') for category in categories] # not nice, but works
print(len(categories))
categories
# Out:
# 21
# ['Earth Observation, Geospatial Concepts, Geospatial Tech and Tools',
#  'mapscaping.com',
#  'Geospatial Career, Geospatial Startups, Geospatial Tech and Tools',
#  'Geospatial Startups, Geospatial Tech and Tools, GIS',
#  'Geospatial Tech and Tools, GIS',
#  'Geospatial Career, Geospatial Tech and Tools, GIS',
#  'Earth Observation, Geospatial Concepts, Geospatial Tech and Tools',
#  'Geospatial Startups, Geospatial Tech and Tools, GIS',
#  'Geospatial Career, Geospatial Tech and Tools, GIS',
#  'Geospatial Tech and Tools',
#  'Geospatial Career, Geospatial Startups, Geospatial Tech and Tools, GIS',
#  'Geospatial Concepts, Geospatial Tech and Tools, GIS',
#  'Earth Observation, Geospatial Startups, Geospatial Tech and Tools',
#  'Earth Observation, Geospatial Career, GIS',
#  'Earth Observation, Geospatial Tech and Tools',
#  'Earth Observation, Geospatial Concepts, Geospatial Tech and Tools',
#  'Geospatial Career, Geospatial Tech and Tools, GIS',
#  'Geospatial Career, GIS',
#  'Earth Observation, Geospatial Tech and Tools, GIS',
#  'Earth Observation, Geospatial Tech and Tools, GIS',
#  'Earth Observation, Geospatial Career, Geospatial Startups, GIS']

# %%
duration_soup = soup.findAll('span', class_= "blog-meta-time-slt")
durations = [duration.text for duration in duration_soup]
durations.insert(16, '35:53')
print(len(durations))
durations
# Out:
# 21
# ['44:16',
#  '35:52',
#  '44:56',
#  '59:04',
#  '50:35',
#  '51:06',
#  '41:26',
#  '48:00',
#  '26:10',
#  '49:35',
#  '41:54',
#  '44:58',
#  '53:12',
#  '40:34',
#  '40:59',
#  '39:33',
#  '35:53',
#  '43:41',
#  '33:42',
#  '49:00',
#  '30:27']

# %%
df_page3 = pd.DataFrame({'Episode': episodes, 'Date': dates, 'Title': titles, 'Duration': durations, 'Categories': categories})
df_page3['Date'] = pd.to_datetime(df_page3['Date'])
df_page3['Episode'] = df_page3['Episode'].str.replace('Episode ', '')

df_page3.info()
df_page3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Episode     21 non-null     object
#  1   Date        21 non-null     datetime64[ns]
#  2   Title       21 non-null     object
#  3   Duration    21 non-null     object
#  4   Categories  21 non-null     object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 968.0+ bytes
#    Episode       Date                                              Title  \
# 0      167 2022-08-10                  Bathymetric Lidar and Blue Carbon
# 1      166 2022-08-08       Re-Published – QGIS Offline And In The Field
# 2      165 2022-08-03                     The Open Geospatial Consortium
# 3      164 2022-07-27       Monetizing An Open-Source Geospatial Project
# 4      161 2022-07-20    Whitebox Tools Is The Backend To Many Frontends
# 5      163 2022-07-20                      QGIS Offline And In The Field
# 6      160 2022-07-06                                       Sentinel Hub
# 7      159 2022-06-29                     Unstructured Data Is Dark Data
# 8      158 2022-06-25                                What Is Modern GIS?
# 9      157 2022-06-08                                             FOSS4G
# 10     156 2022-06-01  Building a web based mapping tool into a business
# 11     155 2022-04-28                Digital twins – not just a buzzword
# 12     154 2022-04-20                                Build Your Own SaaS
# 13     153 2022-04-13        Getting Your Dream Job in Earth Observation
# 14     152 2022-04-06                             Fake Satellite Imagery
# 15     151 2022-03-30                            Cloud Native Geospatial
# 16     162 2022-03-18                                        Python Maps
# 17     150 2022-03-09           Mentorship, Leadership and Career Advice
# 18     149 2022-03-02  The Role Of Geospatial In Open Source Intellig...
# 19     148 2022-02-23  Geospatial Design and User Experience Can Redu...
# 20     147 2022-02-16               Business Ideas For Geospatial People
#
#    Duration                                         Categories
# 0     44:16  Earth Observation, Geospatial Concepts, Geospa...
# 1     35:52                                     mapscaping.com
# 2     44:56  Geospatial Career, Geospatial Startups, Geospa...
# 3     59:04  Geospatial Startups, Geospatial Tech and Tools...
# 4     50:35                     Geospatial Tech and Tools, GIS
# 5     51:06  Geospatial Career, Geospatial Tech and Tools, GIS
# 6     41:26  Earth Observation, Geospatial Concepts, Geospa...
# 7     48:00  Geospatial Startups, Geospatial Tech and Tools...
# 8     26:10  Geospatial Career, Geospatial Tech and Tools, GIS
# 9     49:35                          Geospatial Tech and Tools
# 10    41:54  Geospatial Career, Geospatial Startups, Geospa...
# 11    44:58  Geospatial Concepts, Geospatial Tech and Tools...
# 12    53:12  Earth Observation, Geospatial Startups, Geospa...
# 13    40:34          Earth Observation, Geospatial Career, GIS
# 14    40:59       Earth Observation, Geospatial Tech and Tools
# 15    39:33  Earth Observation, Geospatial Concepts, Geospa...
# 16    35:53  Geospatial Career, Geospatial Tech and Tools, GIS
# 17    43:41                             Geospatial Career, GIS
# 18    33:42  Earth Observation, Geospatial Tech and Tools, GIS
# 19    49:00  Earth Observation, Geospatial Tech and Tools, GIS
# 20    30:27  Earth Observation, Geospatial Career, Geospati...

# %%
df_complete = pd.concat([result_df, df_page3], ignore_index = True)

# %%
final_df = df_complete.sort_values(by='Date')
final_df
# Out:
#     Episode       Date                                              Title  \
# 208       1 2019-01-14  The future of collecting and updating geospati...
# 207       2 2019-02-08  Indoor mapping and navigation: Manage, visuali...
# 206       3 2019-03-10                    Bellerby & Co – The globemakers
# 205       4 2019-04-02         freelance mappers create maps for machines
# 204       5 2019-04-08  Powering location intelligence with geo social...
# 203       6 2019-04-16              Data discovery – the way it should be
# 202       7 2019-04-25  Augmented reality will change the way you thin...
# 201       8 2019-05-03  Geo-tagged audio – another way of augmenting r...
# 200       9 2019-05-08  Proof of location, bringing the blockchain to ...
# 199      10 2019-05-15                Mapping Personalised Workplace Risk
# 198      11 2019-05-22  Translating between machine and human when tal...
# 197      12 2019-05-29           Tracking global air traffic in real time
# 196      13 2019-06-05     A mapping platform for your outdoor adventures
# 195      14 2019-06-12  Scaling map data generation using computer vision
# 194      15 2019-06-19  A diary of your location – recording your trav...
# 193      16 2019-06-25  Positioning as a service and the role of smart...
# 192      17 2019-07-03             Creating Global Activity Specific Maps
# 191      18 2019-07-10  Mapping the way we relate to the urban environ...
# 190      19 2019-07-17           A geospatial story and some housekeeping
# 189      20 2019-07-31  The Google Drive of geospatial – curation over...
# 188      21 2019-08-08  Immersive maps give context to data – this is ...
# 187      22 2019-08-14  Highways in the sky, risk islands and drone fl...
# 186      23 2019-08-21  Crowd source clean the planet – a geospatial a...
# 185      24 2019-08-28    Geospatial support for humanitarian emergencies
# 184      25 2019-09-04            Inspirational geospatial visualizations
# 183      26 2019-09-11                   Geospatial gives context to risk
# 182      27 2019-09-18                      The location context platform
# 181      28 2019-09-25  Using the geomagnetic field of buildings to na...
# 180      29 2019-10-02  Geospatial visualisations matter – Civil engin...
# 179      30 2019-10-09    A marketplace for geospatial data and workflows
# 178      31 2019-10-16     Remote sensing and future of earth observation
# 177      32 2019-10-23                       Building footprints at scale
# 176      33 2019-10-30  Geomob – Geoinnovation for the people by the p...
# 175      34 2019-11-06                      Creating maps for journalists
# 174      35 2019-11-13  Mapping the interface between vehicle traffic ...
# 173      36 2019-11-20                     Building geospatial truth sets
# 172      37 2019-11-27             Don’t just make the dots, connect them
# 171      38 2019-12-04  Addressing the world – a coordinate system fro...
# 170      39 2019-12-11          Remote sensing – building the globe in 3D
# 169      40 2019-12-18  Travel Time – A better way of doing location b...
# 168      41 2019-12-26  Trends in geospatial and initiatives in the co...
# 167      42 2020-01-15  The evolution of geospatial file formats and d...
# 166      43 2020-01-22  Geospatial intelligence from the sky, automati...
# 165      44 2020-01-29              Is R the language of geospatial data?
# 164      45 2020-02-05  Geo-coding as a tool for risk assessment and t...
# 163      46 2020-02-12  PostgreSQL – An open source geospatial databas...
# 162      47 2020-02-19  Earth Observation – machine learning and artif...
# 161      48 2020-02-26                              Serverless Geospatial
# 160      49 2020-03-03                                A Case Study in GIS
# 159      50 2020-03-12            QGIS – An opensource geospatial project
# 158      51 2020-03-18  Disrupting ESRI – Why it is hard to build a bi...
# 157      52 2020-03-25              Earth Observation, platforms and data
# 156      53 2020-04-01    Dynamic vector tiles straight from the database
# 155      54 2020-04-08  The overlap between Business Intelligence tool...
# 154      55 2020-04-15  Advice for job seekers from a geospatial recru...
# 153      56 2020-04-22  Robotics, remote sensing and facilities manage...
# 152      57 2020-04-29  GIS vs Computer-aided design – everything you ...
# 151      58 2020-05-06                          Rebranding GIS Geospatial
# 150      59 2020-05-13  Two mobile data collection apps you need to kn...
# 149      60 2020-05-20                                  Geospatial Python
# 148      61 2020-05-27                                      Digital Twins
# 147      62 2020-06-03                     Hyper-accurate indoor location
# 146      63 2020-06-10                    Radio Frequency Data Collection
# 145      64 2020-06-17                   Jupyter notebooks for geospatial
# 144      65 2020-06-24                              Polygons of Ownership
# 143      66 2020-07-01  Everything happens somewhere And at some time ...
# 142      67 2020-07-08              Spatially Enabling Customer Relations
# 141      68 2020-07-15                     The Spatial Internet of Things
# 140      69 2020-07-22                      A one to one map of the world
# 53      177 2022-10-28                            Artificial Intelligence
# 52      178 2022-11-02                             Full Stack Cartography
# 51      179 2022-11-15                       Cloud Optimized Point Clouds
# 50      180 2022-11-30  Reduce and Reverse Tropical Forest Loss With N...
# 49      181 2022-12-07                How Google Calculates Your Location
# 48      182 2023-01-11  geospatial consulting – as a business and a ca...
# 47      183 2023-01-18    ChronoCards – Building a Business on ArcGIS Pro
# 46      184 2023-01-25        The technology stack and the cultural stack
# 45      185 2023-02-01               Aerial Imagery: The State Of The Art
# 44      186 2023-02-08  Geospatial Support for the UN World Food Progr...
# 43      187 2023-02-15                       Distributing Geospatial Data
# 42      188 2023-02-22               Making Money With Geospatial Content
# 41      189 2023-03-01       Navigating the World of Geospatial Standards
# 40      190 2023-03-08                             Geospatial Archaeology
# 39      191 2023-03-15                    Storytelling With  Point Clouds
# 38      192 2023-03-22           Planet Scale Tiled Maps Without A Server
# 37      193 2023-04-02                     All Of The Places In The World
# 36      194 2023-04-13                     Hyperspectral vs Multispectral
# 35      195 2023-04-19                     Designing for Location Privacy
# 34      196 2023-04-26                          Computer Vision and GeoAI
# 33      197 2023-05-07                           Spatial Knowledge Graphs
# 32      198 2023-05-10                  ChatGPT and Large Language Models
# 31      199 2023-05-17                             Rasters In A Database?
# 30      200 2023-05-24                            Big Data In The Browser
# 29      201 2023-05-31              pygeoapi – A Python Geospatial Server
# 28      202 2023-06-07    From Pixels to Patterns: AI in Spatial Analysis
# 27      203 2023-06-14                 Using Lasers To Talk To Satellites
# 26      204 2023-06-22  Applying For A Job, Getting Picked and Negotia...
# 25      205 2023-06-28  PostgreSQL – Listen and Notify Clients In Real...
# 24      206 2023-07-05                                   The Rapid Editor
# 23      207 2023-07-19                             Felt – Upload Anything
# 22      208 2023-08-03                                          Hub Ocean
# 21      209 2023-08-09                   Synthetic Data For Real Problems
# 20      210 2023-08-16                       100 billion Points Every Day
# 19      211 2023-08-30        Overture Maps And The Daylight Distribution
# 18      212 2023-09-19                                   From GNSS to VPS
# 17      213 2023-10-04                        Strategic Buy-In For FOSS4G
# 16      214 2023-11-15                    Entity Resolution with Placekey
# 15      215 2023-11-22                    Personal Branding in Geospatial
# 14      216 2023-11-30  Fire Mapping, Maritime Search And Wide Angle I...
# 13      217 2023-12-06    Planet – Imaging Everything, Every Day … Almost
# 12      218 2023-12-14                      Making Beautiful Maps In Felt
# 11      219 2023-12-20                   The Business of QGIS Development
# 10      220 2023-12-27                                     GPS Reimagined
# 9       221 2024-01-09                                             GeeMap
# 8       222 2024-01-26            Introduction to Cloud Native Geospatial
# 7       223 2024-02-15               Introduction To LIDAR & Point Clouds
# 6       224 2024-02-29                                  Modern Geospatial
# 5       225 2024-03-15  The Way You Talk About Your Geospatial Skills ...
# 4       226 2024-03-21  GNSS receivers – why precise positioning will ...
# 3       227 2024-04-12                           AI Autocomplete for QGIS
# 2       228 2024-05-01                          What is humanitarian GIS?
# 1       229 2024-05-16                              Finding Stuff Indoors
# 0       230 2024-05-23                           GeoParquet for beginners
# 62      39:55  Earth Observation, Geospatial Concepts, Geospa...
# 61      39:50  Earth Observation, Geospatial Startups, Geospa...
# 60      52:32  Geospatial Startups, Geospatial Tech and Tools...
# 59      43:06  Geospatial Concepts, Geospatial Tech and Tools...
# 58      38:53       Earth Observation, Geospatial Tech and Tools
# 57      13:08                             Geospatial Career, GIS
# 56      38:51  Earth Observation, Geospatial Career, Geospati...
# 55      41:48  Geospatial Career, Geospatial Tech and Tools, GIS
# 54      59:43                             Geospatial Career, GIS
# 53      45:30  Earth Observation, Geospatial Career, Geospati...
# 52      56:31  Geospatial Concepts, Geospatial Tech and Tools...
# 51      37:52  Geospatial Concepts, Geospatial Tech and Tools...
# 50      37:45                                  Earth Observation
# 49      43:52     Geospatial Concepts, Geospatial Tech and Tools
# 48      46:52                             Geospatial Career, GIS
# 47      43:26             Geospatial Career, Geospatial Startups
# 46      50:57                                Geospatial Concepts
# 45      52:07  Earth Observation, Geospatial Concepts, Geospa...
# 44      41:39               Earth Observation, Geospatial Career
# 43      51:11     Geospatial Concepts, Geospatial Tech and Tools
# 42      38:50                                  Geospatial Career
# 41      46:51  Geospatial Concepts, Geospatial Tech and Tools...
# 40      45:54       Geospatial Career, Geospatial Tech and Tools
# 39      39:42                     Geospatial Tech and Tools, GIS
# 38      37:59  Geospatial Concepts, Geospatial Tech and Tools...
# 37      42:29                     Geospatial Tech and Tools, GIS
# 36      38:46  Earth Observation, Geospatial Concepts, Geospa...
# 35      42:18                           Geospatial Concepts, GIS
# 34      37:58  Earth Observation, Geospatial Concepts, Geospa...
# 33      32:04                                Geospatial Concepts
# 32      50:13  Geospatial Concepts, Geospatial Tech and Tools...
# 31      34:21  Geospatial Concepts, Geospatial Tech and Tools...
# 30      57:17     Geospatial Concepts, Geospatial Tech and Tools
# 29      37:03                     Geospatial Tech and Tools, GIS
# 28   01:05:50                                Geospatial Concepts
# 27      44:51  Earth Observation, Geospatial Concepts, Geospa...
# 26   01:00:07                                  Geospatial Career
# 25      26:28                     Geospatial Tech and Tools, GIS
# 24      51:59                     Geospatial Tech and Tools, GIS
# 23      39:30                     Geospatial Tech and Tools, GIS
# 22      38:53           Geospatial Concepts, Geospatial Startups
# 21   01:02:36  Earth Observation, Geospatial Startups, Geospa...
# 20      49:07     Geospatial Concepts, Geospatial Tech and Tools
# 19      52:23  Geospatial Concepts, Geospatial Tech and Tools...
# 18      54:59                                     mapscaping.com
# 17      45:47                                     mapscaping.com
# 16      40:25                                     mapscaping.com
# 15      50:12                                     mapscaping.com
# 14      46:27                                     mapscaping.com
# 13      45:19                                     mapscaping.com
# 12      52:36                                     mapscaping.com
# 11      52:26                                     mapscaping.com
# 10      45:36                                     mapscaping.com
# 9       54:55                                     mapscaping.com
# 8       55:13                                     mapscaping.com
# 7       48:52                                     mapscaping.com
# 6       48:25                                     mapscaping.com
# 5       52:17                                     mapscaping.com
# 4       51:01                                     mapscaping.com
# 3       42:52                                     mapscaping.com
# 2       47:24                                     mapscaping.com
# 1       49:37                                     mapscaping.com
# 0       42:00                                     mapscaping.com

# %%
final_df.to_csv('MapScaping_scraped.tsv', sep='\t', index = False)

# %% [markdown]
# # Interviewee info

# %% [markdown]
# this is the more tricky part. Daniel does not list the names or contact information of his interview partners is a structured way on his website. Therefore, I have to manually go through the transcripts (those he has, luckily!) to find the names of the interview partners and then browse the internet to find social media profiles etc. with data on them

# %% [markdown]
# #### Variables I try to find for each interviewee are:
# * (interviewee id)
# * first name
# * last name
# * gender (based on pronouns on LinkedIn or how other people/websites refer to them)
# * position/seniority *at time of interview*
# * weblinks (to LinkedIn/Twitter/personal page and to company page)
# * company name *at time of interview*

# %% [markdown]
# #### Shortcomings
# * not everyone is 'from' somewhere. Several interviewees moved quite often in their lives and don't consider themselves to be from a specific place
# * gender is assumed from name & photos if not explicitly stated on LinkedIn or clear from how Daniel refers to them
# * the location I use is point data, while some interviewees state a region (or even country) as their location
# * quite a few companies that the interviewees worked at the time of the interview were acquired by other firms or were closed
# *

# %% [markdown]
# some names can't be written correctly because of UTF8 encoding
# * Lyden Foust
# * Josh Kopecek
# * Markus Müller
#
#
# * several place names (especially PL, CZ)

# %% [markdown]
# Not sure whether the map is too much advertisement for the interview partners / their companies. Daniel does not want the podcast to be a sales pitch for them.

# %% [markdown]
# ### Struggles
# I use Excel to type in the data that I found on line.
# Now I can't read in the csv file into python because of UTF-8 encoing issues...

# %%
with open("MapScaping_extended.csv", 'rb') as f:
  contents = f.read()

# %%
contents

# %%
import os

## from 
## https://stackoverflow.com/questions/48812580/python-pandas-unicodedecodeerror-utf-8-codec-cant-decode-byte-0xcd-in-pos

def read_csv(filepath):
     if os.path.splitext(filepath)[1] != '.csv':
          return  # or whatever
     seps = [',', ';', '\t']                    # ',' is default
     encodings = [None, 'utf-8', 'ISO-8859-1']  # None is default
     for sep in seps:
         for encoding in encodings:
              try:
                  return pd.read_csv(filepath, encoding=encoding, sep=sep)
              except Exception:  # should really be more specific 
                  pass
     raise ValueError("{!r} is has no encoding in {} or seperator in {}"
                      .format(filepath, encodings, seps))

# %%
df = read_csv("MapScaping_extended.csv")

# %%
# double square brackets to keep it as DataFrame (instead of Series)
locations = df[['location']]
# drop duplicate locations to make geocoding faster and avoid merge complications later on
locations = locations.drop_duplicates(subset='location')

locations #.info()

# %% [markdown]
# #### Nomatim API to geocode addresses

# %%
import pandas as pd
import requests
import time

# Load addresses from CSV
addresses_df = locations # pd.read_csv('location.csv')
addresses = addresses_df['location'].tolist()

# Function to geocode address using Nominatim API
def geocode_address(address):
    url = 'https://nominatim.openstreetmap.org/search'
    headers = {'User-Agent': 'Nicolas'}
    params = {'q': address, 'format': 'json'}
    
    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        results = response.json()
        if results:
            return results[0]['lat'], results[0]['lon']  # Return the latitude and longitude of the first result
    return None, None  # Return None if no results or an error occurred

# Create a list to hold geocoded results
geocoded_addresses = []

# Geocode each address
for address in tqdm(addresses):
    lat, lon = geocode_address(address)
    geocoded_addresses.append({'address': address, 'latitude': lat, 'longitude': lon})
    time.sleep(1)  # Sleep to respect Nominatim's usage policy

# Convert results to a DataFrame
geocoded_df = pd.DataFrame(geocoded_addresses)

# Optionally, save the geocoded results to a new CSV file
geocoded_df.to_csv('geocoded_addresses.csv', index=False)

print('Geocoding complete. Results saved to geocoded_addresses.csv.')

# %%
geocoded_df
# manually insert coordinates for...
# ...Bellerby & Co., as it's too specific for nomatim 
geocoded_df.at[2, 'latitude'] = 51.5625709
geocoded_df.at[2, 'longitude'] = -0.0788484
# ...Cologne-Bonn-Region in Germany, as it's unknown to nomatim 
geocoded_df.at[112, 'latitude'] = 50.8285133
geocoded_df.at[112, 'longitude'] = 6.9960294
# ...NaN, as geocoding this makes no sense at all ;)
geocoded_df.at[1, 'latitude'] = 'NaN'
geocoded_df.at[1, 'longitude'] = 'NaN'

geocoded_df

# %%
# drop rows without location / coordinates
# create explicit copy of the DataFrame
geocoded_df_clean = geocoded_df.dropna().copy()
geocoded_df_clean.info()

# %%
# transform into float and round to 7 decimal points (approx 1cm)
geocoded_df_clean.loc[:, 'latitude'] = geocoded_df_clean['latitude'].astype(float).round(7)
geocoded_df_clean.loc[:, 'longitude'] = geocoded_df_clean['longitude'].astype(float).round(7)

# %%
geocoded_df_clean = geocoded_df_clean.rename(columns={'address': 'location'})
geocoded_df_clean.info()
df#.info()

# %%
# merge geocoded coordinates to main dataframe
result_df = pd.merge(df, geocoded_df_clean, on='location', how='left')

# %% [markdown]
# result_df.sort_values(by=['Duration'])
# # transform 'duration' to timedelta
# # difficult, because excel changed the time format ...
# # -> use columns from original scraped final_df?
# result_df['Duration'] = pd.to_timedelta(result_df['Duration'].replace('',np.NaN))
# result_df.groupby('gender')['Duration'].mean()

# %%
result_df['Date'] = pd.to_datetime(result_df['Date'], format='%d.%m.%y')
# check that datetime conversion worked properly
result_df = result_df.sort_values(by=['Date'])
result_df.info()

# %%
# result_df = result_df.drop(multiple_guest)
result_df# .info()

# %%
# result_df = result_df.rename(columns={'address': 'location'})

# %%
# Creating a combined name column for convenience
result_df['full_name'] = result_df['first_name'] + ' ' + result_df['last_name']

# Counting occurrences and creating a new column
result_df['number_of_interviews'] = result_df.groupby('full_name')['full_name'].transform('count') #.astype(int)

# %%
# who appears how often?
result_df.sort_values(by=['number_of_interviews', 'full_name'], ascending = False)

# %%
result_df.info()

# %%
# subset only first columns to check that file is okay
subset = result_df[['Episode', 'Date', 'Title', 'Duration', 'Categories', 'first_name', 'last_name', 'interviewee_link', 'gender', 'position', 'company_name', 'company_link', 'location', 'latitude', 'longitude', 'full_name', 'number_of_interviews']]

#

# %%
subset.info()

# %%
data = {'Episode': [1, 2, 2, 3, 4, 4, 5],
        'Title': ['A', 'B', 'B', 'C', 'D', 'D', 'E']}
result_df = pd.DataFrame(data)
result_df

# %%
# save as tab-separated file so that commas in addresses don't mess it up
subset.to_csv('geocoded_addresses.tsv', sep='\t', index = False)

# %% [markdown]
# ### To Do Preprocessing
# * rename variables to be meaningful
# * create variable with count of interviews per person
# * change data types to time / timedelta? Or only later in postgis??
#
#
#
#
#
# ### To Do Frontend
# * jitter points so that they are not exactly on top of each other
# * clustering of points that overlap too much (solve css problems)
#     * use colorcoding for percentage of male/female interviewees in cluster
# * handle special characters correctly (in names)
# * include more in popup
#     * interviewee name (make link clickable)
#     * episode
#     * company name (make link clickable)
# * allow filtering for
#     * category (use regex to check whether category is in string)
#     * gender
#     * date (range filter?)
#     * number of interviews (checkbox)
#     * interviewee name?
#     * company name?

# %% [markdown]
# To introduce a jitter of approximately 1 kilometer to the locations in your interviewees table to ensure that identical locations don’t overlay each other, you can use the ST_Translate function in PostGIS. This function shifts the geometry by a specified amount in the x (longitude) and y (latitude) directions. The amount to shift can be determined based on the degree equivalent of the desired distance at the given latitude (keeping in mind that a degree of longitude varies in actual distance depending on the latitude, but for small distances like 1km, this can be approximated fairly accurately).
#
# For the jitter, we can use random offsets in both the latitude and longitude directions. Given that 1 degree of latitude is approximately 111 kilometers, a shift of about 0.009° in any direction would approximate to 1 kilometer. For longitude, this value needs to be adjusted based on the latitude due to the varying distance covered by a degree of longitude, but for simplicity, we'll use the same approximation, which is reasonable for small distances and near the equator.
#
# This SQL statement will move each point in a random direction by up to approximately 1 kilometer. The RANDOM() function generates a value between 0 and 1, so RANDOM() * 0.018 - 0.009 will produce a shift ranging from -0.009° to +0.009° in both latitude and longitude, effectively creating a jitter around the original point.

# %% [markdown]
# not needed
# * interviewee_id
# * page_on_website
# * incomplete

# %% [markdown]
# **Attention!!!**
# * there are two different Eric Jensen's
# * Peter Petrik's episode was re-published because of audio-quality

# %% [markdown]
# ## troubleshooting

# %%
# !pip install qiskit
# Out:
# python(14510) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Collecting qiskit
#   Downloading qiskit-1.0.2-cp38-abi3-macosx_10_9_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy<2,>=1.17 in /Users/nf/opt/anaconda3/lib/python3.9/site-packages (from qiskit) (1.22.4)
# Requirement already satisfied: sympy>=1.3 in /Users/nf/opt/anaconda3/lib/python3.9/site-packages (from qiskit) (1.10.1)
# Collecting stevedore>=3.0.0
#   Downloading stevedore-5.2.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 11.9 MB/s eta 0:00:01
# Collecting rustworkx>=0.14.0
#   Downloading rustworkx-0.14.2-cp39-cp39-macosx_10_12_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 44.0 MB/s eta 0:00:01�█████████████████▏     | 1.5 MB 44.0 MB/s eta 0:00:01
# Requirement already satisfied: scipy>=1.5 in /Users/nf/opt/anaconda3/lib/python3.9/site-packages (from qiskit) (1.7.3)
# Requirement already satisfied: typing-extensions in /Users/nf/opt/anaconda3/lib/python3.9/site-packages (from qiskit) (4.1.1)
# Collecting symengine>=0.11
#   Downloading symengine-0.11.0-cp39-cp39-macosx_10_9_x86_64.whl (23.8 MB)
#      |████████████████████████████████| 23.8 MB 1.2 MB/s eta 0:00:011
# Collecting dill>=0.3
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      |████████████████████████████████| 116 kB 37.7 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/nf/opt/anaconda3/lib/python3.9/site-packages (from qiskit) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/nf/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.0->qiskit) (1.16.0)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-6.0.0-py2.py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 45.3 MB/s eta 0:00:01
# Requirement already satisfied: mpmath>=0.19 in /Users/nf/opt/anaconda3/lib/python3.9/site-packages (from sympy>=1.3->qiskit) (1.2.1)
# Installing collected packages: pbr, symengine, stevedore, rustworkx, dill, qiskit
# Successfully installed dill-0.3.8 pbr-6.0.0 qiskit-1.0.2 rustworkx-0.14.2 stevedore-5.2.0 symengine-0.11.0
